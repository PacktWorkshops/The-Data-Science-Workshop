# %%
import socket
import threading
import requests
import json
from flask import Flask, jsonify, request

# %%
ip_address = socket.gethostbyname(socket.gethostname())
ip_address
# Out:
# '172.28.0.2'

# %%
app = Flask(__name__)

# %%
@app.route("/")
def welcome():
    return "Welcome to my API!"

# %%
flask_thread = threading.Thread(target=app.run, kwargs={'host':'0.0.0.0','port':80})
flask_thread.start()
# Out:
#  * Serving Flask app "__main__" (lazy loading)

# %%
r = requests.get(f"http://{ip_address}")
r.text
# Out:
# 172.28.0.2 - - [25/Nov/2019 03:04:39] "GET / HTTP/1.1" 200 -
# 'Welcome to my API!'

# %%
@app.route('/empty', methods=['POST'])
def check_empty():
  data = request.get_json()
  return jsonify(not data)

# %%
empty_json = json.dumps([])

# %%
headers = {'content-type': 'application/json', 'Accept-Charset': 'UTF-8'}

# %%
r_empty = requests.post(f"http://{ip_address}/empty", data=empty_json, headers=headers)
r_empty.text
# Out:
# 172.28.0.2 - - [25/Nov/2019 03:04:59] "POST /empty HTTP/1.1" 200 -
# 'true\n'

# %%
not_empty_json = json.dumps(['Data Science', 'is', 'so', 'cool', '!'])

# %%
r_not_empty = requests.post(f"http://{ip_address}/empty", data=not_empty_json, headers=headers)
r_not_empty.text
# Out:
# 172.28.0.2 - - [25/Nov/2019 03:05:01] "POST /empty HTTP/1.1" 200 -
# 'false\n'

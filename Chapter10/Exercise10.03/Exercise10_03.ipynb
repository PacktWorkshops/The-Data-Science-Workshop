# %%
import pandas as pd

# %%
file_url = 'https://raw.githubusercontent.com/PacktWorkshops/The-Data-Science-Workshop/master/Chapter10/dataset/ames_iowa_housing.csv'

# %%
df = pd.read_csv(file_url)

# %%
num_df = df.select_dtypes(include='number')

# %%
num_cols = num_df.columns
num_cols
# Out:
# Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
#        'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
#        'MiscVal', 'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
def describe_numeric(df, col_name):
    print(f"\nCOLUMN: {col_name}")
    print(f"Minimum: {df[col_name].min()}")
    print(f"Maximum: {df[col_name].max()}")
    print(f"Average: {df[col_name].mean()}")
    print(f"Standard Deviation: {df[col_name].std()}")
    print(f"Median: {df[col_name].median()}")

# %%
describe_numeric(df, 'SalePrice')
# Out:
# COLUMN: SalePrice
# Minimum: 34900
# Maximum: 755000
# Average: 180921.19589041095
# Standard Deviation: 79442.50288288662
# Median: 163000.0

# %%
for col_name in num_cols:
  describe_numeric(df, col_name)
# Out:
# COLUMN: Id
# Minimum: 1
# Maximum: 1460
# Average: 730.5
# Standard Deviation: 421.6100093688479
# Median: 730.5
#
# COLUMN: MSSubClass
# Minimum: 20
# Maximum: 190
# Average: 56.897260273972606
# Standard Deviation: 42.300570993810425
# Median: 50.0
#
# COLUMN: LotFrontage
# Minimum: 21.0
# Maximum: 313.0
# Average: 70.04995836802665
# Standard Deviation: 24.284751774483208
# Median: 69.0
#
# COLUMN: LotArea
# Minimum: 1300
# Maximum: 215245
# Average: 10516.828082191782
# Standard Deviation: 9981.26493237915
# Median: 9478.5
#
# COLUMN: OverallQual
# Minimum: 1
# Maximum: 10
# Average: 6.0993150684931505
# Standard Deviation: 1.3829965467415934
# Median: 6.0
#
# COLUMN: OverallCond
# Minimum: 1
# Maximum: 9
# Average: 5.575342465753424
# Standard Deviation: 1.1127993367127316
# Median: 5.0
#
# COLUMN: YearBuilt
# Minimum: 1872
# Maximum: 2010
# Average: 1971.267808219178
# Standard Deviation: 30.202904042525258
# Median: 1973.0
#
# COLUMN: YearRemodAdd
# Minimum: 1950
# Maximum: 2010
# Average: 1984.8657534246574
# Standard Deviation: 20.645406807709413
# Median: 1994.0
#
# COLUMN: MasVnrArea
# Minimum: 0.0
# Maximum: 1600.0
# Average: 103.68526170798899
# Standard Deviation: 181.0662065872166
# Median: 0.0
#
# COLUMN: BsmtFinSF1
# Minimum: 0
# Maximum: 5644
# Average: 443.6397260273973
# Standard Deviation: 456.0980908409277
# Median: 383.5
#
# COLUMN: BsmtFinSF2
# Minimum: 0
# Maximum: 1474
# Average: 46.54931506849315
# Standard Deviation: 161.31927280654173
# Median: 0.0
#
# COLUMN: BsmtUnfSF
# Minimum: 0
# Maximum: 2336
# Average: 567.2404109589041
# Standard Deviation: 441.86695529243417
# Median: 477.5
#
# COLUMN: TotalBsmtSF
# Minimum: 0
# Maximum: 6110
# Average: 1057.4294520547944
# Standard Deviation: 438.7053244594708
# Median: 991.5
#
# COLUMN: 1stFlrSF
# Minimum: 334
# Maximum: 4692
# Average: 1162.626712328767
# Standard Deviation: 386.5877380410744
# Median: 1087.0
#
# COLUMN: 2ndFlrSF
# Minimum: 0
# Maximum: 2065
# Average: 346.99246575342465
# Standard Deviation: 436.5284358862568
# Median: 0.0
#
# COLUMN: LowQualFinSF
# Minimum: 0
# Maximum: 572
# Average: 5.844520547945206
# Standard Deviation: 48.62308143352019
# Median: 0.0
#
# COLUMN: GrLivArea
# Minimum: 334
# Maximum: 5642
# Average: 1515.463698630137
# Standard Deviation: 525.4803834232025
# Median: 1464.0
#
# COLUMN: BsmtFullBath
# Minimum: 0
# Maximum: 3
# Average: 0.42534246575342466
# Standard Deviation: 0.5189106060898065
# Median: 0.0
#
# COLUMN: BsmtHalfBath
# Minimum: 0
# Maximum: 2
# Average: 0.057534246575342465
# Standard Deviation: 0.23875264627921178
# Median: 0.0
#
# COLUMN: FullBath
# Minimum: 0
# Maximum: 3
# Average: 1.5650684931506849
# Standard Deviation: 0.5509158012954317
# Median: 2.0
#
# COLUMN: HalfBath
# Minimum: 0
# Maximum: 2
# Average: 0.38287671232876713
# Standard Deviation: 0.5028853810928914
# Median: 0.0
#
# COLUMN: BedroomAbvGr
# Minimum: 0
# Maximum: 8
# Average: 2.8664383561643834
# Standard Deviation: 0.8157780441442284
# Median: 3.0
#
# COLUMN: KitchenAbvGr
# Minimum: 0
# Maximum: 3
# Average: 1.0465753424657533
# Standard Deviation: 0.22033819838403068
# Median: 1.0
#
# COLUMN: TotRmsAbvGrd
# Minimum: 2
# Maximum: 14
# Average: 6.517808219178082
# Standard Deviation: 1.6253932905840505
# Median: 6.0
#
# COLUMN: Fireplaces
# Minimum: 0
# Maximum: 3
# Average: 0.613013698630137
# Standard Deviation: 0.6446663863122295
# Median: 1.0
#
# COLUMN: GarageYrBlt
# Minimum: 1900.0
# Maximum: 2010.0
# Average: 1978.5061638868744
# Standard Deviation: 24.689724768590242
# Median: 1980.0
#
# COLUMN: GarageCars
# Minimum: 0
# Maximum: 4
# Average: 1.7671232876712328
# Standard Deviation: 0.7473150101111095
# Median: 2.0
#
# COLUMN: GarageArea
# Minimum: 0
# Maximum: 1418
# Average: 472.9801369863014
# Standard Deviation: 213.80484145338042
# Median: 480.0
#
# COLUMN: WoodDeckSF
# Minimum: 0
# Maximum: 857
# Average: 94.2445205479452
# Standard Deviation: 125.3387943517241
# Median: 0.0
#
# COLUMN: OpenPorchSF
# Minimum: 0
# Maximum: 547
# Average: 46.66027397260274
# Standard Deviation: 66.25602767664971
# Median: 25.0
#
# COLUMN: EnclosedPorch
# Minimum: 0
# Maximum: 552
# Average: 21.954109589041096
# Standard Deviation: 61.1191486017286
# Median: 0.0
#
# COLUMN: 3SsnPorch
# Minimum: 0
# Maximum: 508
# Average: 3.4095890410958902
# Standard Deviation: 29.31733055678188
# Median: 0.0
#
# COLUMN: ScreenPorch
# Minimum: 0
# Maximum: 480
# Average: 15.060958904109588
# Standard Deviation: 55.757415281874174
# Median: 0.0
#
# COLUMN: PoolArea
# Minimum: 0
# Maximum: 738
# Average: 2.758904109589041
# Standard Deviation: 40.17730694453019
# Median: 0.0
#
# COLUMN: MiscVal
# Minimum: 0
# Maximum: 15500
# Average: 43.489041095890414
# Standard Deviation: 496.12302445794415
# Median: 0.0
#
# COLUMN: MoSold
# Minimum: 1
# Maximum: 12
# Average: 6.321917808219178
# Standard Deviation: 2.7036262083595126
# Median: 6.0
#
# COLUMN: YrSold
# Minimum: 2006
# Maximum: 2010
# Average: 2007.8157534246575
# Standard Deviation: 1.3280951205521099
# Median: 2008.0
#
# COLUMN: SalePrice
# Minimum: 34900
# Maximum: 755000
# Average: 180921.19589041095
# Standard Deviation: 79442.50288288662
# Median: 163000.0

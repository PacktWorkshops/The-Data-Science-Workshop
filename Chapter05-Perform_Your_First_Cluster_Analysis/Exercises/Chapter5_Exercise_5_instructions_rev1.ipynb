# %% [markdown]
# ## Exercise 5: Standardise the data

# %% [markdown]
# In this final exercise, we will standardise the data using min-max scaler and z-score and fit a k-means for each method and see their impact on k-means.

# %% [markdown]
# ---
#
# 1. Open on a new Colab notebook. Import the required packages (**pandas**, **sklearn**, **altair**)
#
#
#
# ---

# %%
# Put your code here #

# %% [markdown]
# ---
#
#
# 2. Load the dataset and select the same columns as in exercise 1 using read_csv() method from the package pandas.
#
#
#
# ---

# %%
# Put your code here #

# %% [markdown]
# ---
#
#
# 3. Assign the columns ‘Average total business income’ and ‘Average total business expenses’ to a new variable called X:
#
#
# ---

# %%
# Put your code here #

# %% [markdown]
# ---
#
#
#
# 4. Import the classes MinMaxScaler and StandardScaler from sklearn
#
#
#
# ---

# %%
# Put your code here #

# %% [markdown]
# ---
#
# 5. Instantiate and fit the MinMaxScaler with the data
#
#
# ---

# %%
# Put your code here #

# %% [markdown]
# ---
#
#
# 5. Perform the min-max scaling transformation and save the data into a new variable called ‘X_min_max’.
#
# ---

# %%
# Put your code here #

# %% [markdown]
# Expected output:
#
# ![Figure 55 - Min-max scaled data](https://docs.google.com/uc?export=download&id=1QI4wuA_Y_JEtIlPbus4fHApxefSKLROu)

# %% [markdown]
# ---
#
# 7. Fit a k-means on the scaled data with the following hyperparameters: random_state=1, n_clusters=4, init='k-means++' and n_init=5
#
#
# ---

# %%
# Put your code here #

# %% [markdown]
# ---
#
# 8. Assign the k-means predictions of each value of X into a new column called ‘cluster8’ on the df dataframe
#
#
# ---

# %%
# Put your code here #

# %% [markdown]
# ---
#
# 9. Plot the k-means results into a scatter plot using altair package
#
#
# ---

# %%
# Put your code here #

# %% [markdown]
# Expected output:
#
# ![Figure 56 - Scatter plot of k-means results using the min-max scaled data](https://docs.google.com/uc?export=download&id=1nxxKJhZicFg4Zo-T-QrG6jDqe_Y-xKk-)

# %% [markdown]
# ---
#
#
# 10. Re-train a k-means but on the z-score standardised data with the same hyperparameters values random_state=1, n_clusters=4, init='k-means++' and n_init=5
#
#
# ---

# %%
# Put your code here #

# %% [markdown]
# ---
#
# 11. Assign the k-means predictions of each value of X_scaled into a new column called ‘cluster9’ on the df dataframe
#
#
# ---

# %%
# Put your code here #

# %% [markdown]
# ---
#
# 12. Plot the k-means results into a scatter plot using altair package
#
#
# ---

# %%
# Put your code here #

# %% [markdown]
# Expected output:
#
# ![Figure 57 - Scatter plot of k-means results using the z-score standardised data](https://docs.google.com/uc?export=download&id=1-4_0T60NfDX0BhX-avSvpY7qFt3kbT1n)

# %% [markdown]
# The k-means clustering results are very similar between min-max and z-score standardisations. Compared to the results in exercise 3, we can see the boundaries between clusters 1 and 2 are slightly lower after standardisation. The reason why these results are very close to each other is due to the fact that the range of values for the 2 variables (average total business income and average total business expenses) are almost identical: between 0 and 900,000. Therefore k-means is not putting more weights toward one of these variables.

# %% [markdown]
# Well done! You completed the final exercise of this chapter. You have learned how to pre-process the data before fitting the k-means with 2 very popular method: min-max scaling and z-score.
